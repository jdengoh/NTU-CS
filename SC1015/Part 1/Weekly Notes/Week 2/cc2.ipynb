# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
data = pd.read_csv('datahouse.csv')

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17492 entries, 0 to 17491
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                17492 non-null  object
#  1   Street Name          17492 non-null  object
#  2   block                17492 non-null  object
#  3   Town Index           17492 non-null  int64
#  4   Floor Area (sqm)     17492 non-null  float64
#  5   Flat Type Index      17492 non-null  int64
#  6   Storey Index         17492 non-null  int64
#  7   Remaining Years      17492 non-null  int64
#  8   Lease Commence Date  17492 non-null  int64
#  9   Flat Model Index     17492 non-null  int64
#  10  Resale Price         17492 non-null  float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 1.5+ MB

# %%
dataclean = data[["Town Index", "Floor Area (sqm)", 'Flat Type Index', 'Storey Index','Remaining Years','Lease Commence Date','Flat Model Index','Resale Price']]

# %%
f, axes = plt.subplots(figsize = (20,15))
sb.boxplot(x="Flat Type Index", y="Resale Price", data=dataclean)
# Out:
# <AxesSubplot:xlabel='Flat Type Index', ylabel='Resale Price'>

# %%
flattype = data[["Flat Type Index", "Resale Price"]]

# %%
flattype.groupby("Flat Type Index").describe()
# Out:
#                 Resale Price                                          \
#                        count           mean            std       min
# Flat Type Index
# 1                        8.0  230000.000000   13341.664064  202000.0
# 2                      275.0  289355.381818   42706.885151  200000.0
# 3                     4104.0  382976.591128   83559.271018  200000.0
# 4                     7380.0  541993.932190  128931.081916  288000.0
# 5                     4452.0  646846.922875  145122.059501  373888.0
# 6                        7.0  833412.571429   85686.635517  683888.0
# 7                     1266.0  771615.899589  121275.362116  500000.0
#
#
#                       25%       50%       75%        max
# Flat Type Index
# 1                227750.0  230000.0  236250.0   248000.0
# 2                260000.0  290000.0  310000.0   560000.0
# 3                332800.0  365000.0  410000.0   958000.0
# 4                455000.0  506000.0  576625.0  1228000.0
# ...
