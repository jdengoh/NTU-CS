# %%
import numpy as np
import pandas as pd

# %%
column_names = ["Age", "Workclass", "Fnlwgt", "Education", "Education-num", "Marital status", "Occupation", "Relationship", "Race", "Sex", "Capital-gain", "Capital-loss", "Hours-per-week", "Native-country"]
incomedata = pd.read_table('adult.data', sep = ",", header = None)
properdata = pd.dataframe[incomedata], columns = column_names

# "Age", "Workclass", "Fnlwgt", "Education", "Education-num", "Marital status", "Occupation", "Relationship", "Race", "Sex", "Capital-gain", "Capital-loss", "Hours-per-week", "Native-country"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12652/2052149544.py in <module>
#       1 column_names = ["Age", "Workclass", "Fnlwgt", "Education", "Education-num", "Marital status", "Occupation", "Relationship", "Race", "Sex", "Capital-gain", "Capital-loss", "Hours-per-week", "Native-country"]
#       2 incomedata = pd.read_table('adult.data', sep = ",", header = None)
# ----> 3 properdata = pd.dataframe[incomedata], columns = column_names
#       4
#       5 # "Age", "Workclass", "Fnlwgt", "Education", "Education-num", "Marital status", "Occupation", "Relationship", "Race", "Sex", "Capital-gain", "Capital-loss", "Hours-per-week", "Native-country"
#
# ValueError: too many values to unpack (expected 2)

# %%
print(type(incomedata))
incomedata.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (32561, 15)

# %%
incomedata.head(50)
# Out:
#     0                  1       2              3   4                       5   \
# 0   39          State-gov   77516      Bachelors  13           Never-married
# 1   50   Self-emp-not-inc   83311      Bachelors  13      Married-civ-spouse
# 2   38            Private  215646        HS-grad   9                Divorced
# 3   53            Private  234721           11th   7      Married-civ-spouse
# 4   28            Private  338409      Bachelors  13      Married-civ-spouse
# 5   37            Private  284582        Masters  14      Married-civ-spouse
# 6   49            Private  160187            9th   5   Married-spouse-absent
# 7   52   Self-emp-not-inc  209642        HS-grad   9      Married-civ-spouse
# 8   31            Private   45781        Masters  14           Never-married
# 9   42            Private  159449      Bachelors  13      Married-civ-spouse
# 10  37            Private  280464   Some-college  10      Married-civ-spouse
# ...

# %%
incomedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32561 non-null  object
# dtypes: object(1)
# memory usage: 254.5+ KB

# %%
incomedata.describe()
# Out:
#                                                         0
# count                                               32561
# unique                                              32537
# top     25, Private, 195994, 1st-4th, 2, Never-married...
# freq                                                    3
