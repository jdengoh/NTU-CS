# %%
import numpy as np
import pandas as pd

# %%
wikidata = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')

# %%
print(type(wikidata))
# Out:
# <class 'list'>

# %%
print(len(wikidata))
# Out:
# 7

# %%
wikidata[2].head(15)
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1  United States    46      37      38    121
# 1     2  Great Britain    27      23      17     67
# 2     3          China    26      18      26     70
# 3     4         Russia    19      17      20     56
# 4     5        Germany    17      10      15     42
# 5     6          Japan    12       8      21     41
# 6     7         France    10      18      14     42
# 7     8    South Korea     9       3       9     21
# 8     9          Italy     8      12       8     28
# 9    10      Australia     8      11      10     29
# 10   11    Netherlands     8       7       4     19
# 11   12        Hungary     8       3       4     15
# 12   13        Brazil*     7       6       6     19
# 13   14          Spain     7       4       6     17
# 14   15          Kenya     6       6       1     13

# %%
# Extract single variable

# medaldata = pd.DataFrame(wikidata[2]) works

medaldata = wikidata[2]

# %%
print(type(medaldata))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(medaldata.shape)

print(medaldata.size)
# Out:
# (87, 6)
# 522

# %%
# iloc[] -> row settings, followed by column settings (BY INDEX)
# think of it as 'slicing'

medal_first20 = medaldata.iloc[:20, :]
medal_first20
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1  United States    46      37      38    121
# 1     2  Great Britain    27      23      17     67
# 2     3          China    26      18      26     70
# 3     4         Russia    19      17      20     56
# 4     5        Germany    17      10      15     42
# 5     6          Japan    12       8      21     41
# 6     7         France    10      18      14     42
# 7     8    South Korea     9       3       9     21
# 8     9          Italy     8      12       8     28
# 9    10      Australia     8      11      10     29
# 10   11    Netherlands     8       7       4     19
# 11   12        Hungary     8       3       4     15
# 12   13        Brazil*     7       6       6     19
# 13   14          Spain     7       4       6     17
# 14   15          Kenya     6       6       1     13
# 15   16        Jamaica     6       3       2     11
# 16   17        Croatia     5       3       2     10
# ...

# %%
#choosing column (one or more) BY NAME, and how many rows to get from that column

medaldata.loc[:5, ('NOC', 'Total')]
# Out:
#              NOC  Total
# 0  United States    121
# 1  Great Britain     67
# 2          China     70
# 3         Russia     56
# 4        Germany     42
# 5          Japan     41
